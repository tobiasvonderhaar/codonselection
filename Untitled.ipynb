# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %run Scripts/GR.py

# %%
pdata = process_GR('RawData/110522_2uC_media_dependence.csv', normalise=False)

# %%
pdata
# Out:
#       Plasmid    Rel_GR
# 0     2u:C+NS  0.258170
# 1   2u:C+Gluc  0.256390
# 2    2u:C+YNB  0.257299
# 3     2u:C+AA  0.265512
# 4     2u:C+SC  0.262924
# 5     2u:C+NS  0.262613
# 6     2u:C+NS  0.259449
# 7   2u:C+Gluc  0.244911
# 8    2u:C+YNB  0.247785
# 9     2u:C+AA  0.262573
# 10    2u:C+SC  0.259718
# 11    2u:C+NS  0.262133
# 12    2u:C+NS  0.261697
# 13  2u:C+Gluc  0.257953
# 14   2u:C+YNB  0.251866
# 15    2u:C+AA  0.260405
# 16    2u:C+SC  0.256867
# 17    2u:C+NS  0.257404
# 18    2u:C+NS  0.251785
# 19  2u:C+Gluc  0.252547
# 20   2u:C+YNB  0.248052
# 21    2u:C+AA  0.256319
# 22    2u:C+SC  0.251338
# 23    2u:C+NS  0.261313
